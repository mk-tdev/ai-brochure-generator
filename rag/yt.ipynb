# %% [markdown]
# ### Python way of things

# %%
def extract_relevant_context(words, knowledge):
  relevant_context = []

  return 
  [knowledge[word] for word in words if word in knowledge]
  

words = ["python", "java"]
knowledge = {
    "python": "A high-level programming language.",
    "java": "A class-based, object-oriented programming language.",
    "javascript": "A programming language commonly used in web development."
}

context = extract_relevant_context(words, knowledge)
print(context)
# Out:
# ['A high-level programming language.', 'A class-based, object-oriented programming language.']
